# %% [markdown]
# 예수께서 나아와 말씀하여 이르시되 하늘과 땅의 모든 권세를 내게 주셨으니
# 그러므로 너희는 가서 모든 민족을 제자로 삼아 아버지와 아들과 성령의 이름으로 세례를 베풀고
# 내가 너희에게 분부한 모든 것을 가르쳐 지키게 하라 볼지어다 내가 세상 끝날까지 너희와 항상 함께 있으리라 하시니라 (마28:18-20)
#
# -------
# <center><img src="https://github.com/idebtor/DSpy/blob/6b3676c3de29f85d2e7f30679676d1fd96d88b17/images/WelcomeToDataStructures.jpg?raw=true" width=1000></center>
#
# __NOTE:__ The following materials have been compiled and adapted from the numerous sources including my own. Please help me to keep this tutorial up-to-date by reporting any issues or questions. Send any comments or criticisms to `idebtor@gmail.com` Your assistances and comments will be appreciated.
#
# --------

# %% [markdown]
# <b style="font-size:30px">Problem Set: JSON </b>
#
#
# Honor Code:

# %% [markdown]
# # JSON파일을 파이썬 객체화하기(디코딩, 역직렬화)
#
# - `json.load()`: 파일에 있는 JSON 포맷 데이터를 Python 객체로 읽어오기 (역직렬화 혹은 디코딩이라고 부르기도 합니다)
# - `json.loads()`: 메모리에 있는 JSON 형식의 문자열로 되어 있는 입력자료를 받아 파이썬 객체로 전환합니다.
#
# <img src="https://github.com/idebtor/DSpy/blob/b67467b971cf48c14faf7c8ebed7a94871dbb2ad/images/chap1/Chapter%201-25json_load.jpg?raw=true" width="100%">
# <center>그림1. load() and loads() 비교</center>

# %% [markdown]
# # 파이썬 객체로 JSON파일 만들기(인코딩, 직렬화)
#
# - `json.dump()`: Python객체를 파일에 저장할 때(직렬화, 인코딩) 사용합니다.
# - `json.dumps()`: Python객체를 문자열로 출력할 때 사용합니다.
#
# <img src="https://github.com/idebtor/DSpy/blob/b67467b971cf48c14faf7c8ebed7a94871dbb2ad/images/chap1/Chapter%201-27json_dump.jpg?raw=true" width="100%">
#
# <center>그림2. dump() and dumps() 비교</center>

# %% [markdown]
# # JSON Exercise - JSON file
#
# ## Code 편집기로 작성한 `companies.json`작성하기
#
# 코드(텍스트) 편집기를 사용하여 아래의 내용을 가진 파일(`companies.json`)을 작성하십시오.
# ```json
# [
#     {
#         "name": "Big Corpration",
#         "numberOfEmployee": 10000,
#         "ceo": "June",
#         "rating": 3.9
#     },
#     {
#         "name": "Small Start-up",
#         "numberOfEmployee": 5,
#         "ceo": null,
#         "rating": 4.5
#     }
# ]
# ```

# %% [markdown]
# ## Code 편집기로 작성한 companies.json을 읽고 출력하기
#
# - `with open()`을 사용하면, `close()`을 호출할 필요가 없습니다.
#
# __Sample Run:__
#
# ```json
# [{'name': 'Big Corpration', 'numberOfEmployee': 10000, 'ceo': 'June', 'rating': 3.9}, {'name': 'Small Start-up', 'numberOfEmployee': 5, 'ceo': None, 'rating': 4.5}]
# ```

# %%
import json
with open('companies.json','r') as f:
    companies=json.load(f)
print(companies)
# Out:
# [{'name': 'Big Corpration', 'numberOfEmployee': 10000, 'ceo': 'June', 'rating': 3.9}, {'name': 'Small Start-up', 'numberOfEmployee': 5, 'ceo': None, 'rating': 4.5}]

# %% [markdown]
# ## 자료를 하나씩 출력하기
#
# 각 회사(`company`)별로 출력합니다
#
# __Sample Run:__
#
# ```json
# {'name': 'Big Corpration', 'numberOfEmployee': 10000, 'ceo': 'June', 'rating': 3.9}
# {'name': 'Small Start-up', 'numberOfEmployee': 5, 'ceo': None, 'rating': 4.5}
# ```

# %%
for company in companies:
    print(company)
# Out:
# {'name': 'Big Corpration', 'numberOfEmployee': 10000, 'ceo': 'June', 'rating': 3.9}
# {'name': 'Small Start-up', 'numberOfEmployee': 5, 'ceo': None, 'rating': 4.5}

# %% [markdown]
# ## 자료를 정렬하고 읽기 쉽게 포맷하기
# - 각 회사의 자료에서 `numberOfEmployee`를 삭제하십시오.
# - `indent = 2`를 추가하고 필요에 따라 `sorted_keys = True` 추가합니다.
# - 아래와 같이 출력하십시오.

# %% [markdown]
# __Sample Run:__
# ```json
# [
#   {
#     "ceo": "June",
#     "name": "Big Corpration",
#     "rating": 3.9
#   },
#   {
#     "ceo": null,
#     "name": "Small Start-up",
#     "rating": 4.5
#   }
# ]
# ```

# %%
for company in companies:
    del(company['numberOfEmployee'])
    
sorted = json.dumps(companies, indent=2, sort_keys = True)
print(sorted)
# Out:
# [
#   {
#     "ceo": "June",
#     "name": "Big Corpration",
#     "rating": 3.9
#   },
#   {
#     "ceo": null,
#     "name": "Small Start-up",
#     "rating": 4.5
#   }
# ]

# %% [markdown]
# ## 새로운 JSON 파일(`companies_new.json`)에 저장하기
# 아래와 같은 내용으로 JSON파일(`companies_new.json`)을 작성하십시오.
#
# __Sample Run:__ Expected JSON File
# ```json
# [
#   {
#     "ceo": "June",
#     "name": "Big Corpration",
#     "rating": 3.9
#   },
#   {
#     "ceo": null,
#     "name": "Small Start-up",
#     "rating": 4.5
#   }
# ]
# ```
# - 가독성(readability)를 높이기 위하여 `indent = 2`를 인자로 사용하는 것이 좋습니다.
# - `with open()`을 사용하면, `close()`을 호출할 필요가 없습니다.

# %% [markdown]
# __Solution__

# %%
with open('companies_new.json','w') as f:
    json.dump(companies,f,indent=2,sort_keys=True)

# %% [markdown]
# ## 위에서 작성한 파일을 읽고 확인하기
#
# __Sample Run:__
#
# ```json
# {'ceo': 'June', 'name': 'Big Corpration', 'rating': 3.9}
# {'ceo': None, 'name': 'Small Start-up', 'rating': 4.5}
# [
#   {
#     "ceo": "June",
#     "name": "Big Corpration",
#     "rating": 3.9
#   },
#   {
#     "ceo": null,
#     "name": "Small Start-up",
#     "rating": 4.5
#   }
# ]
# ```

# %%
with open('companies_new.json','r') as f:
    companies=json.load(f)
    
for company in companies:
    print(company)
    
print(json.dumps(companies, indent = 2, sort_keys = True))
# Out:
# {'ceo': 'June', 'name': 'Big Corpration', 'rating': 3.9}
# {'ceo': None, 'name': 'Small Start-up', 'rating': 4.5}
# [
#   {
#     "ceo": "June",
#     "name": "Big Corpration",
#     "rating": 3.9
#   },
#   {
#     "ceo": null,
#     "name": "Small Start-up",
#     "rating": 4.5
#   }
# ]

# %% [markdown]
# # JSON Exercise: Exchange Rate Extraction
#
# 지금까지 경험해 본 JSON과 파이썬 코딩을 활용하여, 실생활 데이터를 가지고 응용하는 문제를 다루어 보도록 하겠습니다.
#
# 이제는 대부분의 자료 제공자들이 JSON 파일 형식으로 자료를 제공합니다. 여기 연습문제로 무료로 140 여개의 환율 정보를 제공하는 Website에서 JSON 파일로 원화(KRW)에 대한 각 국가의 환율 정보를 가져옵니다. 그러한 환율 정보 중에서 몇 개의 특정한 통화를 계산해보는 응용 문제를 시도해봅니다.

# %% [markdown]
# ## JSON 파일을 다운받아 파이썬 객체로 변환하기
# - 파일을 읽을 때는 `load()`를 사용하고, 문자열(String)을 읽을 때는`loads()`를 사용합니다.

# %%
import json
from urllib.request import urlopen

with urlopen("http://www.floatrates.com/daily/krw.json") as response:
    source = response.read()

rates = json.loads(source)

# %% [markdown]
# ## 파이썬 객체로 변환한 것을 출력하기
# - 가독성을 위해 `ident = 2`로 설정하는 것이 필요합니다.
#
# __Sample Run:__
# ```json
# {
#   "usd": {
#     "code": "USD",
#     "alphaCode": "USD",
#     "numericCode": "840",
#     "name": "U.S. Dollar",
#     "rate": 0.00086484208312665,
#     "date": "Sat, 4 Sep 2021 23:55:01 GMT",
#     "inverseRate": 1156.2804580285
#   },
#   "eur": {
#     "code": "EUR",
#     "alphaCode": "EUR",
#     "numericCode": "978",
#     "name": "Euro",
#   ...
# }
# ```

# %%
print(json.dumps(rates,indent=2))
# Out:
# {
#   "usd": {
#     "code": "USD",
#     "alphaCode": "USD",
#     "numericCode": "840",
#     "name": "U.S. Dollar",
#     "rate": 0.00082475717453957,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 1212.4780855144
#   },
#   "eur": {
#     "code": "EUR",
#     "alphaCode": "EUR",
#     "numericCode": "978",
#     "name": "Euro",
#     "rate": 0.00074596961214103,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 1340.5371796981
#   },
#   "gbp": {
#     "code": "GBP",
#     "alphaCode": "GBP",
#     "numericCode": "826",
#     "name": "U.K. Pound Sterling",
#     "rate": 0.00062633348065572,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 1596.5935574018
#   },
#   "cad": {
#     "code": "CAD",
#     "alphaCode": "CAD",
#     "numericCode": "124",
#     "name": "Canadian Dollar",
#     "rate": 0.0010423232459695,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 959.39527768071
#   },
#   "jpy": {
#     "code": "JPY",
#     "alphaCode": "JPY",
#     "numericCode": "392",
#     "name": "Japanese Yen",
#     "rate": 0.097860642412073,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 10.218612665439
#   },
#   "aud": {
#     "code": "AUD",
#     "alphaCode": "AUD",
#     "numericCode": "036",
#     "name": "Australian Dollar",
#     "rate": 0.0011202490433524,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 892.65865115804
#   },
#   "chf": {
#     "code": "CHF",
#     "alphaCode": "CHF",
#     "numericCode": "756",
#     "name": "Swiss Franc",
#     "rate": 0.00077452339026491,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 1291.1165919185
#   },
#   "ghs": {
#     "code": "GHS",
#     "alphaCode": "GHS",
#     "numericCode": "936",
#     "name": "Ghanaian Cedi",
#     "rate": 0.006005610341528,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 166.51096943222
#   },
#   "cup": {
#     "code": "CUP",
#     "alphaCode": "CUP",
#     "numericCode": "192",
#     "name": "Cuban peso",
#     "rate": 0.00082242702561551,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 1215.9133501864
#   },
#   "jod": {
#     "code": "JOD",
#     "alphaCode": "JOD",
#     "numericCode": "400",
#     "name": "Jordanian Dinar",
#     "rate": 0.00058436489124357,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 1711.2595485878
#   },
#   "bgn": {
#     "code": "BGN",
#     "alphaCode": "BGN",
#     "numericCode": "975",
#     "name": "Bulgarian Lev",
#     "rate": 0.0014588440422927,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 685.47423234384
#   },
#   "pgk": {
#     "code": "PGK",
#     "alphaCode": "PGK",
#     "numericCode": "598",
#     "name": "Papua New Guinean kina",
#     "rate": 0.0029038307602044,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 344.37268648866
#   },
#   "uzs": {
#     "code": "UZS",
#     "alphaCode": "UZS",
#     "numericCode": "860",
#     "name": "Uzbekistan Sum",
#     "rate": 9.0621233423006,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.11034941395381
#   },
#   "mga": {
#     "code": "MGA",
#     "alphaCode": "MGA",
#     "numericCode": "969",
#     "name": "Malagasy ariary",
#     "rate": 3.3291970371513,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.30037272917186
#   },
#   "srd": {
#     "code": "SRD",
#     "alphaCode": "SRD",
#     "numericCode": "968",
#     "name": "Surinamese dollar",
#     "rate": 0.016958548220058,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 58.967311766535
#   },
#   "zmw": {
#     "code": "ZMW",
#     "alphaCode": "ZMW",
#     "numericCode": "967",
#     "name": "Zambian kwacha",
#     "rate": 0.014621380096746,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 68.392996651701
#   },
#   "yer": {
#     "code": "YER",
#     "alphaCode": "YER",
#     "numericCode": "886",
#     "name": "Yemeni rial",
#     "rate": 0.20584948076127,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 4.8579184960866
#   },
#   "sek": {
#     "code": "SEK",
#     "alphaCode": "SEK",
#     "numericCode": "752",
#     "name": "Swedish Krona",
#     "rate": 0.0077858595531055,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 128.43797055151
#   },
#   "lkr": {
#     "code": "LKR",
#     "alphaCode": "LKR",
#     "numericCode": "144",
#     "name": "Sri Lanka Rupee",
#     "rate": 0.21977896030737,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 4.5500260743862
#   },
#   "pln": {
#     "code": "PLN",
#     "alphaCode": "PLN",
#     "numericCode": "985",
#     "name": "Polish Zloty",
#     "rate": 0.0035024974983411,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 285.51055367595
#   },
#   "rub": {
#     "code": "RUB",
#     "alphaCode": "RUB",
#     "numericCode": "643",
#     "name": "Russian Rouble",
#     "rate": 0.084250490098443,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 11.86936715539
#   },
#   "azn": {
#     "code": "AZN",
#     "alphaCode": "AZN",
#     "numericCode": "944",
#     "name": "Azerbaijan Manat",
#     "rate": 0.0014179247392682,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 705.25604942623
#   },
#   "nio": {
#     "code": "NIO",
#     "alphaCode": "NIO",
#     "numericCode": "558",
#     "name": "Nicaraguan C\u00f3rdoba",
#     "rate": 0.029425985507987,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 33.983568697421
#   },
#   "sbd": {
#     "code": "SBD",
#     "alphaCode": "SBD",
#     "numericCode": "090",
#     "name": "Solomon Islands dollar",
#     "rate": 0.0065689863209737,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 152.23048901886
#   },
#   "all": {
#     "code": "ALL",
#     "alphaCode": "ALL",
#     "numericCode": "008",
#     "name": "Albanian lek",
#     "rate": 0.092049927226082,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 10.863669642496
#   },
#   "mur": {
#     "code": "MUR",
#     "alphaCode": "MUR",
#     "numericCode": "480",
#     "name": "Mauritian Rupee",
#     "rate": 0.036960025868898,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 27.056258119167
#   },
#   "dop": {
#     "code": "DOP",
#     "alphaCode": "DOP",
#     "numericCode": "214",
#     "name": "Dominican Peso",
#     "rate": 0.045257196484744,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 22.09593341331
#   },
#   "nzd": {
#     "code": "NZD",
#     "alphaCode": "NZD",
#     "numericCode": "554",
#     "name": "New Zealand Dollar",
#     "rate": 0.0012002057752671,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 833.1904583424
#   },
#   "hrk": {
#     "code": "HRK",
#     "alphaCode": "HRK",
#     "numericCode": "191",
#     "name": "Croatian Kuna",
#     "rate": 0.0056456361645834,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 177.12795703579
#   },
#   "dzd": {
#     "code": "DZD",
#     "alphaCode": "DZD",
#     "numericCode": "012",
#     "name": "Algerian Dinar",
#     "rate": 0.11775203461561,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 8.4924222605954
#   },
#   "ars": {
#     "code": "ARS",
#     "alphaCode": "ARS",
#     "numericCode": "032",
#     "name": "Argentine Peso",
#     "rate": 0.090088686254332,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 11.100172969299
#   },
#   "stn": {
#     "code": "STN",
#     "alphaCode": "STN",
#     "numericCode": "930",
#     "name": "S\u00e3o Tom\u00e9 and Pr\u00edncipe Dobra",
#     "rate": 0.018518877314964,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 53.998953769837
#   },
#   "bif": {
#     "code": "BIF",
#     "alphaCode": "BIF",
#     "numericCode": "108",
#     "name": "Burundian franc",
#     "rate": 1.686920720932,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.59279608554901
#   },
#   "szl": {
#     "code": "SZL",
#     "alphaCode": "SZL",
#     "numericCode": "748",
#     "name": "Swazi lilangeni",
#     "rate": 0.012402431215867,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 80.629352632142
#   },
#   "sos": {
#     "code": "SOS",
#     "alphaCode": "SOS",
#     "numericCode": "706",
#     "name": "Somali shilling",
#     "rate": 0.47592088438129,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 2.1011895733469
#   },
#   "ang": {
#     "code": "ANG",
#     "alphaCode": "ANG",
#     "numericCode": "532",
#     "name": "Neth. Antillean Guilder",
#     "rate": 0.0014758037533165,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 677.59686730212
#   },
#   "pkr": {
#     "code": "PKR",
#     "alphaCode": "PKR",
#     "numericCode": "586",
#     "name": "Pakistani Rupee",
#     "rate": 0.14849541264918,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 6.7342147623273
#   },
#   "mxn": {
#     "code": "MXN",
#     "alphaCode": "MXN",
#     "numericCode": "484",
#     "name": "Mexican Peso",
#     "rate": 0.016954105521942,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 58.982763715008
#   },
#   "uah": {
#     "code": "UAH",
#     "alphaCode": "UAH",
#     "numericCode": "980",
#     "name": "Ukrainian Hryvnia",
#     "rate": 0.0246305527844,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 40.599982012314
#   },
#   "crc": {
#     "code": "CRC",
#     "alphaCode": "CRC",
#     "numericCode": "188",
#     "name": "Costa Rican Col\u00f3n",
#     "rate": 0.52963660493841,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 1.8880870216972
#   },
#   "bzd": {
#     "code": "BZD",
#     "alphaCode": "BZD",
#     "numericCode": "084",
#     "name": "Belize dollar",
#     "rate": 0.0016582507722358,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 603.04509833077
#   },
#   "gnf": {
#     "code": "GNF",
#     "alphaCode": "GNF",
#     "numericCode": "324",
#     "name": "Guinean franc",
#     "rate": 7.3534247709939,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.13599105602393
#   },
#   "ern": {
#     "code": "ERN",
#     "alphaCode": "ERN",
#     "numericCode": "232",
#     "name": "Eritrean nakfa",
#     "rate": 0.012398065699775,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 80.657743249267
#   },
#   "wst": {
#     "code": "WST",
#     "alphaCode": "WST",
#     "numericCode": "882",
#     "name": "Samoan tala",
#     "rate": 0.0021221174028835,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 471.22746302406
#   },
#   "egp": {
#     "code": "EGP",
#     "alphaCode": "EGP",
#     "numericCode": "818",
#     "name": "Egyptian Pound",
#     "rate": 0.012961303123613,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 77.152736145658
#   },
#   "sgd": {
#     "code": "SGD",
#     "alphaCode": "SGD",
#     "numericCode": "702",
#     "name": "Singapore Dollar",
#     "rate": 0.0011176543630341,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 894.73099472837
#   },
#   "xaf": {
#     "code": "XAF",
#     "alphaCode": "XAF",
#     "numericCode": "950",
#     "name": "Central African CFA Franc",
#     "rate": 0.49115830519192,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 2.036003442127
#   },
#   "amd": {
#     "code": "AMD",
#     "alphaCode": "AMD",
#     "numericCode": "051",
#     "name": "Armenia Dram",
#     "rate": 0.4121428930528,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 2.4263429428392
#   },
#   "pyg": {
#     "code": "PYG",
#     "alphaCode": "PYG",
#     "numericCode": "600",
#     "name": "Paraguayan Guaran\u00ed",
#     "rate": 5.7503008956901,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.17390394313965
#   },
#   "gyd": {
#     "code": "GYD",
#     "alphaCode": "GYD",
#     "numericCode": "328",
#     "name": "Guyanese dollar",
#     "rate": 0.17203724066163,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 5.8126949499664
#   },
#   "rwf": {
#     "code": "RWF",
#     "alphaCode": "RWF",
#     "numericCode": "646",
#     "name": "Rwandan franc",
#     "rate": 0.83525977360823,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 1.1972323241189
#   },
#   "syp": {
#     "code": "SYP",
#     "alphaCode": "SYP",
#     "numericCode": "760",
#     "name": "Syrian pound",
#     "rate": 2.0719355678271,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.4826404911079
#   },
#   "mop": {
#     "code": "MOP",
#     "alphaCode": "MOP",
#     "numericCode": "446",
#     "name": "Macanese pataca",
#     "rate": 0.006630817894025,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 150.81095816266
#   },
#   "bam": {
#     "code": "BAM",
#     "alphaCode": "BAM",
#     "numericCode": "977",
#     "name": "Bosnia and Herzegovina convertible mark",
#     "rate": 0.0014674375975112,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 681.45998282723
#   },
#   "inr": {
#     "code": "INR",
#     "alphaCode": "INR",
#     "numericCode": "356",
#     "name": "Indian Rupee",
#     "rate": 0.06259223988001,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 15.97642138893
#   },
#   "try": {
#     "code": "TRY",
#     "alphaCode": "TRY",
#     "numericCode": "949",
#     "name": "Turkish Lira",
#     "rate": 0.012151360530108,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 82.295311502134
#   },
#   "vnd": {
#     "code": "VND",
#     "alphaCode": "VND",
#     "numericCode": "704",
#     "name": "Vietnamese Dong",
#     "rate": 18.870919841109,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.052991587501821
#   },
#   "kgs": {
#     "code": "KGS",
#     "alphaCode": "KGS",
#     "numericCode": "417",
#     "name": "Kyrgyzstan Som",
#     "rate": 0.079116375772706,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 12.639608301484
#   },
#   "afn": {
#     "code": "AFN",
#     "alphaCode": "AFN",
#     "numericCode": "971",
#     "name": "Afghan afghani",
#     "rate": 0.072185479358667,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 13.853201625653
#   },
#   "nad": {
#     "code": "NAD",
#     "alphaCode": "NAD",
#     "numericCode": "516",
#     "name": "Namibian dollar",
#     "rate": 0.012402431215867,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 80.629352632142
#   },
#   "mwk": {
#     "code": "MWK",
#     "alphaCode": "MWK",
#     "numericCode": "454",
#     "name": "Malawian kwacha",
#     "rate": 0.6637065131536,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 1.5066900507703
#   },
#   "gtq": {
#     "code": "GTQ",
#     "alphaCode": "GTQ",
#     "numericCode": "320",
#     "name": "Guatemalan Quetzal",
#     "rate": 0.0063384748340942,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 157.76665935803
#   },
#   "nok": {
#     "code": "NOK",
#     "alphaCode": "NOK",
#     "numericCode": "578",
#     "name": "Norwegian Krone",
#     "rate": 0.0072842630309794,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 137.28224746238
#   },
#   "lbp": {
#     "code": "LBP",
#     "alphaCode": "LBP",
#     "numericCode": "422",
#     "name": "Lebanese Pound",
#     "rate": 1.253508880812,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.79776060250346
#   },
#   "huf": {
#     "code": "HUF",
#     "alphaCode": "HUF",
#     "numericCode": "348",
#     "name": "Hungarian Forint",
#     "rate": 0.27748957415099,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 3.6037389983375
#   },
#   "pen": {
#     "code": "PEN",
#     "alphaCode": "PEN",
#     "numericCode": "604",
#     "name": "Peruvian Nuevo Sol",
#     "rate": 0.003078177482318,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 324.86755742458
#   },
#   "rsd": {
#     "code": "RSD",
#     "alphaCode": "RSD",
#     "numericCode": "941",
#     "name": "Serbian Dinar",
#     "rate": 0.088001727730305,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 11.363413262347
#   },
#   "svc": {
#     "code": "SVC",
#     "alphaCode": "SVC",
#     "numericCode": "222",
#     "name": "Salvadoran colon",
#     "rate": 0.0072015752715317,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 138.85850835345
#   },
#   "xcd": {
#     "code": "XCD",
#     "alphaCode": "XCD",
#     "numericCode": "951",
#     "name": "East Caribbean Dollar",
#     "rate": 0.0022307096043737,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 448.28784438787
#   },
#   "mmk": {
#     "code": "MMK",
#     "alphaCode": "MMK",
#     "numericCode": "104",
#     "name": "Myanma Kyat",
#     "rate": 1.4627452098447,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.68364606034577
#   },
#   "mvr": {
#     "code": "MVR",
#     "alphaCode": "MVR",
#     "numericCode": "462",
#     "name": "Maldivian rufiyaa",
#     "rate": 0.012720442272684,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 78.613618816339
#   },
#   "ves": {
#     "code": "VES",
#     "alphaCode": "VES",
#     "numericCode": "928",
#     "name": "Venezuelan Bolivar",
#     "rate": 0.0035261711783311,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 283.59371948395
#   },
#   "npr": {
#     "code": "NPR",
#     "alphaCode": "NPR",
#     "numericCode": "524",
#     "name": "Nepalese Rupee",
#     "rate": 0.10057177266684,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 9.9431477986637
#   },
#   "isk": {
#     "code": "ISK",
#     "alphaCode": "ISK",
#     "numericCode": "352",
#     "name": "Icelandic Krona",
#     "rate": 0.10609716702835,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 9.4253223531674
#   },
#   "gip": {
#     "code": "GIP",
#     "alphaCode": "GIP",
#     "numericCode": "292",
#     "name": "Gibraltar pound",
#     "rate": 0.0006282277047123,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 1591.7795291406
#   },
#   "gel": {
#     "code": "GEL",
#     "alphaCode": "GEL",
#     "numericCode": "981",
#     "name": "Georgian lari",
#     "rate": 0.0026181667532206,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 381.94664215711
#   },
#   "mkd": {
#     "code": "MKD",
#     "alphaCode": "MKD",
#     "numericCode": "807",
#     "name": "Macedonian denar",
#     "rate": 0.046117765597911,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 21.683617734622
#   },
#   "awg": {
#     "code": "AWG",
#     "alphaCode": "AWG",
#     "numericCode": "533",
#     "name": "Aruban florin",
#     "rate": 0.0014892146394834,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 671.49487621672
#   },
#   "sll": {
#     "code": "SLL",
#     "alphaCode": "SLL",
#     "numericCode": "694",
#     "name": "Sierra Leonean leone",
#     "rate": 9.5714414818099,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.1044774710163
#   },
#   "kes": {
#     "code": "KES",
#     "alphaCode": "KES",
#     "numericCode": "404",
#     "name": "Kenyan shilling",
#     "rate": 0.094028042319975,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 10.635125174648
#   },
#   "aed": {
#     "code": "AED",
#     "alphaCode": "AED",
#     "numericCode": "784",
#     "name": "U.A.E Dirham",
#     "rate": 0.0030348468218266,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 329.50592194901
#   },
#   "php": {
#     "code": "PHP",
#     "alphaCode": "PHP",
#     "numericCode": "608",
#     "name": "Philippine Peso",
#     "rate": 0.043067182193103,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 23.219536293697
#   },
#   "mro": {
#     "code": "MRO",
#     "alphaCode": "MRO",
#     "numericCode": "478",
#     "name": "Mauritanian Ouguiya",
#     "rate": 0.030012643972909,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 33.319290393164
#   },
#   "cop": {
#     "code": "COP",
#     "alphaCode": "COP",
#     "numericCode": "170",
#     "name": "Colombian Peso",
#     "rate": 3.1556646915096,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.31689044868757
#   },
#   "bbd": {
#     "code": "BBD",
#     "alphaCode": "BBD",
#     "numericCode": "052",
#     "name": "Barbadian Dollar",
#     "rate": 0.0016610660058034,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 602.02303611431
#   },
#   "djf": {
#     "code": "DJF",
#     "alphaCode": "DJF",
#     "numericCode": "262",
#     "name": "Djiboutian franc",
#     "rate": 0.14645089457013,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 6.8282273244917
#   },
#   "mzn": {
#     "code": "MZN",
#     "alphaCode": "MZN",
#     "numericCode": "943",
#     "name": "Mozambican metical",
#     "rate": 0.05272889918123,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 18.964932238827
#   },
#   "ugx": {
#     "code": "UGX",
#     "alphaCode": "UGX",
#     "numericCode": "800",
#     "name": "Ugandan shilling",
#     "rate": 2.9475234019298,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.33926787463173
#   },
#   "brl": {
#     "code": "BRL",
#     "alphaCode": "BRL",
#     "numericCode": "986",
#     "name": "Brazilian Real",
#     "rate": 0.0041901704566864,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 238.65377562487
#   },
#   "cny": {
#     "code": "CNY",
#     "alphaCode": "CNY",
#     "numericCode": "156",
#     "name": "Chinese Yuan",
#     "rate": 0.0052409836286351,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 190.80387783246
#   },
#   "sar": {
#     "code": "SAR",
#     "alphaCode": "SAR",
#     "numericCode": "682",
#     "name": "Saudi Riyal",
#     "rate": 0.0030938070363865,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 323.22636422987
#   },
#   "zar": {
#     "code": "ZAR",
#     "alphaCode": "ZAR",
#     "numericCode": "710",
#     "name": "South African Rand",
#     "rate": 0.012340640835983,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 81.03306897031
#   },
#   "mdl": {
#     "code": "MDL",
#     "alphaCode": "MDL",
#     "numericCode": "498",
#     "name": "Moldova Lei",
#     "rate": 0.015182730081112,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 65.864307318753
#   },
#   "pab": {
#     "code": "PAB",
#     "alphaCode": "PAB",
#     "numericCode": "590",
#     "name": "Panamanian Balboa",
#     "rate": 0.00082359210007753,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 1214.1932880438
#   },
#   "fjd": {
#     "code": "FJD",
#     "alphaCode": "FJD",
#     "numericCode": "242",
#     "name": "Fiji Dollar",
#     "rate": 0.0017437944776009,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 573.46207528757
#   },
#   "cdf": {
#     "code": "CDF",
#     "alphaCode": "CDF",
#     "numericCode": "976",
#     "name": "Congolese franc",
#     "rate": 1.6459301239748,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.60755920645346
#   },
#   "sdg": {
#     "code": "SDG",
#     "alphaCode": "SDG",
#     "numericCode": "938",
#     "name": "Sudanese pound",
#     "rate": 0.36690525680273,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 2.7254992439034
#   },
#   "top": {
#     "code": "TOP",
#     "alphaCode": "TOP",
#     "numericCode": "776",
#     "name": "Tongan pa\u02bbanga",
#     "rate": 0.0018414316527113,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 543.05572434775
#   },
#   "vuv": {
#     "code": "VUV",
#     "alphaCode": "VUV",
#     "numericCode": "548",
#     "name": "Vanuatu vatu",
#     "rate": 0.093017415303726,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 10.750674986342
#   },
#   "dkk": {
#     "code": "DKK",
#     "alphaCode": "DKK",
#     "numericCode": "208",
#     "name": "Danish Krone",
#     "rate": 0.0055530243121658,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 180.08204966961
#   },
#   "idr": {
#     "code": "IDR",
#     "alphaCode": "IDR",
#     "numericCode": "360",
#     "name": "Indonesian Rupiah",
#     "rate": 11.831780848493,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.08451813068591
#   },
#   "tnd": {
#     "code": "TND",
#     "alphaCode": "TND",
#     "numericCode": "788",
#     "name": "Tunisian Dinar",
#     "rate": 0.0024372019584215,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 410.30657986491
#   },
#   "twd": {
#     "code": "TWD",
#     "alphaCode": "TWD",
#     "numericCode": "901",
#     "name": "New Taiwan Dollar ",
#     "rate": 0.02335198820597,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 42.8229061774
#   },
#   "iqd": {
#     "code": "IQD",
#     "alphaCode": "IQD",
#     "numericCode": "368",
#     "name": "Iraqi dinar",
#     "rate": 1.219242933324,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.82018109161698
#   },
#   "bob": {
#     "code": "BOB",
#     "alphaCode": "BOB",
#     "numericCode": "068",
#     "name": "Bolivian Boliviano",
#     "rate": 0.0056567032882677,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 176.78141296081
#   },
#   "lrd": {
#     "code": "LRD",
#     "alphaCode": "LRD",
#     "numericCode": "430",
#     "name": "Liberian dollar",
#     "rate": 0.12624697008265,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 7.9209821775944
#   },
#   "lak": {
#     "code": "LAK",
#     "alphaCode": "LAK",
#     "numericCode": "418",
#     "name": "Lao kip",
#     "rate": 9.4431379766921,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.1058970018725
#   },
#   "bwp": {
#     "code": "BWP",
#     "alphaCode": "BWP",
#     "numericCode": "072",
#     "name": "Botswana Pula",
#     "rate": 0.0095610490372045,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 104.59103348479
#   },
#   "kwd": {
#     "code": "KWD",
#     "alphaCode": "KWD",
#     "numericCode": "414",
#     "name": "Kuwaiti Dinar",
#     "rate": 0.00025049333135413,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 3992.1222437106
#   },
#   "czk": {
#     "code": "CZK",
#     "alphaCode": "CZK",
#     "numericCode": "203",
#     "name": "Czech Koruna",
#     "rate": 0.018481758857053,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 54.107404372847
#   },
#   "ngn": {
#     "code": "NGN",
#     "alphaCode": "NGN",
#     "numericCode": "566",
#     "name": "Nigerian Naira",
#     "rate": 0.34241851391953,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 2.9204028384838
#   },
#   "tmt": {
#     "code": "TMT",
#     "alphaCode": "TMT",
#     "numericCode": "934",
#     "name": "New Turkmenistan Manat",
#     "rate": 0.002921080477786,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 342.3390788459
#   },
#   "etb": {
#     "code": "ETB",
#     "alphaCode": "ETB",
#     "numericCode": "230",
#     "name": "Ethiopian birr",
#     "rate": 0.042233698624774,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 23.677774681411
#   },
#   "ttd": {
#     "code": "TTD",
#     "alphaCode": "TTD",
#     "numericCode": "780",
#     "name": "Trinidad Tobago Dollar",
#     "rate": 0.0055856176106978,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 179.03123158391
#   },
#   "aoa": {
#     "code": "AOA",
#     "alphaCode": "AOA",
#     "numericCode": "973",
#     "name": "Angolan kwanza",
#     "rate": 0.38285765927239,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 2.6119367754075
#   },
#   "khr": {
#     "code": "KHR",
#     "alphaCode": "KHR",
#     "numericCode": "116",
#     "name": "Cambodian riel",
#     "rate": 3.3229155333076,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.30094054151434
#   },
#   "mad": {
#     "code": "MAD",
#     "alphaCode": "MAD",
#     "numericCode": "504",
#     "name": "Moroccan Dirham",
#     "rate": 0.0080591720292808,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 124.08222536593
#   },
#   "ron": {
#     "code": "RON",
#     "alphaCode": "RON",
#     "numericCode": "946",
#     "name": "Romanian New Leu",
#     "rate": 0.0036901350141861,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 270.99279461474
#   },
#   "byn": {
#     "code": "BYN",
#     "alphaCode": "BYN",
#     "numericCode": "933",
#     "name": "Belarussian Ruble",
#     "rate": 0.0024714375306872,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 404.62281064493
#   },
#   "tjs": {
#     "code": "TJS",
#     "alphaCode": "TJS",
#     "numericCode": "972",
#     "name": "Tajikistan Ruble",
#     "rate": 0.010147042114266,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 98.550886922416
#   },
#   "gmd": {
#     "code": "GMD",
#     "alphaCode": "GMD",
#     "numericCode": "270",
#     "name": "Gambian dalasi",
#     "rate": 0.043973663736654,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 22.74088431632
#   },
#   "cve": {
#     "code": "CVE",
#     "alphaCode": "CVE",
#     "numericCode": "132",
#     "name": "Cape Verde escudo",
#     "rate": 0.082877422713086,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 12.066012277697
#   },
#   "hnl": {
#     "code": "HNL",
#     "alphaCode": "HNL",
#     "numericCode": "340",
#     "name": "Honduran Lempira",
#     "rate": 0.020196619640517,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 49.513236264246
#   },
#   "scr": {
#     "code": "SCR",
#     "alphaCode": "SCR",
#     "numericCode": "690",
#     "name": "Seychelles rupee",
#     "rate": 0.012009173083212,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 83.269680024674
#   },
#   "bhd": {
#     "code": "BHD",
#     "alphaCode": "BHD",
#     "numericCode": "048",
#     "name": "Bahrain Dinar",
#     "rate": 0.00031041223902205,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 3221.5224604239
#   },
#   "omr": {
#     "code": "OMR",
#     "alphaCode": "OMR",
#     "numericCode": "512",
#     "name": "Omani Rial",
#     "rate": 0.00031712701079392,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 3153.3107113661
#   },
#   "ils": {
#     "code": "ILS",
#     "alphaCode": "ILS",
#     "numericCode": "376",
#     "name": "Israeli New Sheqel",
#     "rate": 0.0026707298500676,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 374.42948412573
#   },
#   "lyd": {
#     "code": "LYD",
#     "alphaCode": "LYD",
#     "numericCode": "434",
#     "name": "Libyan Dinar",
#     "rate": 0.0038634320858701,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 258.83721462514
#   },
#   "clp": {
#     "code": "CLP",
#     "alphaCode": "CLP",
#     "numericCode": "152",
#     "name": "Chilean Peso",
#     "rate": 0.65945134755095,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 1.5164120957729
#   },
#   "bsd": {
#     "code": "BSD",
#     "alphaCode": "BSD",
#     "numericCode": "044",
#     "name": "Bahamian Dollar",
#     "rate": 0.00082242702561551,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 1215.9133501864
#   },
#   "xpf": {
#     "code": "XPF",
#     "alphaCode": "XPF",
#     "numericCode": "953",
#     "name": "CFP Franc",
#     "rate": 0.089586958956843,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 11.16233893464
#   },
#   "lsl": {
#     "code": "LSL",
#     "alphaCode": "LSL",
#     "numericCode": "426",
#     "name": "Lesotho loti",
#     "rate": 0.01241117147747,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 80.572571397896
#   },
#   "tzs": {
#     "code": "TZS",
#     "alphaCode": "TZS",
#     "numericCode": "834",
#     "name": "Tanzanian shilling",
#     "rate": 1.9060013340401,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.52465860445142
#   },
#   "bdt": {
#     "code": "BDT",
#     "alphaCode": "BDT",
#     "numericCode": "050",
#     "name": "Bangladeshi taka",
#     "rate": 0.071439998609326,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 13.997760630828
#   },
#   "qar": {
#     "code": "QAR",
#     "alphaCode": "QAR",
#     "numericCode": "634",
#     "name": "Qatari Rial",
#     "rate": 0.0030101751258602,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 332.206585394
#   },
#   "myr": {
#     "code": "MYR",
#     "alphaCode": "MYR",
#     "numericCode": "458",
#     "name": "Malaysian Ringgit",
#     "rate": 0.003465845915856,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 288.52984935801
#   },
#   "kzt": {
#     "code": "KZT",
#     "alphaCode": "KZT",
#     "numericCode": "398",
#     "name": "Kazakhstani Tenge",
#     "rate": 0.38949089442138,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 2.5674541159314
#   },
#   "htg": {
#     "code": "HTG",
#     "alphaCode": "HTG",
#     "numericCode": "332",
#     "name": "Haitian gourde",
#     "rate": 0.087067077624032,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 11.48539754967
#   },
#   "bnd": {
#     "code": "BND",
#     "alphaCode": "BND",
#     "numericCode": "096",
#     "name": "Brunei Dollar",
#     "rate": 0.001120000783906,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 892.8565179325
#   },
#   "kmf": {
#     "code": "KMF",
#     "alphaCode": "KMF",
#     "numericCode": "174",
#     "name": "\tComoro franc",
#     "rate": 0.36886485132539,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 2.7110200291702
#   },
#   "mru": {
#     "code": "MRU",
#     "alphaCode": "MRU",
#     "numericCode": "929",
#     "name": "Mauritanian ouguiya",
#     "rate": 0.029926002254088,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 33.415756354941
#   },
#   "mnt": {
#     "code": "MNT",
#     "alphaCode": "MNT",
#     "numericCode": "496",
#     "name": "Mongolian togrog",
#     "rate": 2.3977470832581,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.41705816555147
#   },
#   "hkd": {
#     "code": "HKD",
#     "alphaCode": "HKD",
#     "numericCode": "344",
#     "name": "Hong Kong Dollar",
#     "rate": 0.0064487068676137,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 155.06984896804
#   },
#   "thb": {
#     "code": "THB",
#     "alphaCode": "THB",
#     "numericCode": "764",
#     "name": "Thai Baht",
#     "rate": 0.027470440930083,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 36.402764795264
#   },
#   "xof": {
#     "code": "XOF",
#     "alphaCode": "XOF",
#     "numericCode": "952",
#     "name": "West African CFA Franc",
#     "rate": 0.49095665152037,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 2.0368397024528
#   },
#   "irr": {
#     "code": "IRR",
#     "alphaCode": "IRR",
#     "numericCode": "364",
#     "name": "Iranian rial",
#     "rate": 35.072648207957,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 0.028512246753387
#   },
#   "uyu": {
#     "code": "UYU",
#     "alphaCode": "UYU",
#     "numericCode": "858",
#     "name": "Uruguayan Peso",
#     "rate": 0.035099184658447,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 28.490690303239
#   },
#   "jmd": {
#     "code": "JMD",
#     "alphaCode": "JMD",
#     "numericCode": "388",
#     "name": "Jamaican Dollar",
#     "rate": 0.12579608804665,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 7.9493727947182
#   },
#   "ssp": {
#     "code": "SSP",
#     "alphaCode": "SSP",
#     "numericCode": "728",
#     "name": "South Sudanese pound",
#     "rate": 0.35375017227139,
#     "date": "Fri, 18 Mar 2022 11:55:01 GMT",
#     "inverseRate": 2.8268537470359
#   }
# }

# %% [markdown]
# ## 파이썬 객체 `rates`의 `type`, 자료(통화)의 수, 각 환율 자료 출력하기
#
# __Sample Run:__
# ```
# <class 'dict'>
# 149
# {'code': 'USD', 'alphaCode': 'USD', 'numericCode': '840', 'name': 'U.S. Dollar', 'rate': 0.00086484208312665, 'date': 'Sat, 4 Sep 2021 23:55:01 GMT', 'inverseRate': 1156.2804580285}
# {'code': 'EUR', 'alphaCode': 'EUR', 'numericCode': '978', 'name': 'Euro', 'rate': 0.00072856130060557, 'date': 'Sat, 4 Sep 2021 23:55:01 GMT', 'inverseRate': 1372.5680998549}
# ...
# ```

# %%
print(type(rates))
print(len(rates))

for item in rates:
    print(rates[item])
# Out:
# <class 'dict'>
# 149
# {'code': 'USD', 'alphaCode': 'USD', 'numericCode': '840', 'name': 'U.S. Dollar', 'rate': 0.00082475717453957, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 1212.4780855144}
# {'code': 'EUR', 'alphaCode': 'EUR', 'numericCode': '978', 'name': 'Euro', 'rate': 0.00074596961214103, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 1340.5371796981}
# {'code': 'GBP', 'alphaCode': 'GBP', 'numericCode': '826', 'name': 'U.K. Pound Sterling', 'rate': 0.00062633348065572, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 1596.5935574018}
# {'code': 'CAD', 'alphaCode': 'CAD', 'numericCode': '124', 'name': 'Canadian Dollar', 'rate': 0.0010423232459695, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 959.39527768071}
# {'code': 'JPY', 'alphaCode': 'JPY', 'numericCode': '392', 'name': 'Japanese Yen', 'rate': 0.097860642412073, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 10.218612665439}
# {'code': 'AUD', 'alphaCode': 'AUD', 'numericCode': '036', 'name': 'Australian Dollar', 'rate': 0.0011202490433524, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 892.65865115804}
# {'code': 'CHF', 'alphaCode': 'CHF', 'numericCode': '756', 'name': 'Swiss Franc', 'rate': 0.00077452339026491, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 1291.1165919185}
# {'code': 'GHS', 'alphaCode': 'GHS', 'numericCode': '936', 'name': 'Ghanaian Cedi', 'rate': 0.006005610341528, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 166.51096943222}
# {'code': 'CUP', 'alphaCode': 'CUP', 'numericCode': '192', 'name': 'Cuban peso', 'rate': 0.00082242702561551, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 1215.9133501864}
# {'code': 'JOD', 'alphaCode': 'JOD', 'numericCode': '400', 'name': 'Jordanian Dinar', 'rate': 0.00058436489124357, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 1711.2595485878}
# {'code': 'BGN', 'alphaCode': 'BGN', 'numericCode': '975', 'name': 'Bulgarian Lev', 'rate': 0.0014588440422927, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 685.47423234384}
# {'code': 'PGK', 'alphaCode': 'PGK', 'numericCode': '598', 'name': 'Papua New Guinean kina', 'rate': 0.0029038307602044, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 344.37268648866}
# {'code': 'UZS', 'alphaCode': 'UZS', 'numericCode': '860', 'name': 'Uzbekistan Sum', 'rate': 9.0621233423006, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.11034941395381}
# {'code': 'MGA', 'alphaCode': 'MGA', 'numericCode': '969', 'name': 'Malagasy ariary', 'rate': 3.3291970371513, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.30037272917186}
# {'code': 'SRD', 'alphaCode': 'SRD', 'numericCode': '968', 'name': 'Surinamese dollar', 'rate': 0.016958548220058, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 58.967311766535}
# {'code': 'ZMW', 'alphaCode': 'ZMW', 'numericCode': '967', 'name': 'Zambian kwacha', 'rate': 0.014621380096746, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 68.392996651701}
# {'code': 'YER', 'alphaCode': 'YER', 'numericCode': '886', 'name': 'Yemeni rial', 'rate': 0.20584948076127, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 4.8579184960866}
# {'code': 'SEK', 'alphaCode': 'SEK', 'numericCode': '752', 'name': 'Swedish Krona', 'rate': 0.0077858595531055, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 128.43797055151}
# {'code': 'LKR', 'alphaCode': 'LKR', 'numericCode': '144', 'name': 'Sri Lanka Rupee', 'rate': 0.21977896030737, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 4.5500260743862}
# {'code': 'PLN', 'alphaCode': 'PLN', 'numericCode': '985', 'name': 'Polish Zloty', 'rate': 0.0035024974983411, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 285.51055367595}
# {'code': 'RUB', 'alphaCode': 'RUB', 'numericCode': '643', 'name': 'Russian Rouble', 'rate': 0.084250490098443, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 11.86936715539}
# {'code': 'AZN', 'alphaCode': 'AZN', 'numericCode': '944', 'name': 'Azerbaijan Manat', 'rate': 0.0014179247392682, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 705.25604942623}
# {'code': 'NIO', 'alphaCode': 'NIO', 'numericCode': '558', 'name': 'Nicaraguan Córdoba', 'rate': 0.029425985507987, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 33.983568697421}
# {'code': 'SBD', 'alphaCode': 'SBD', 'numericCode': '090', 'name': 'Solomon Islands dollar', 'rate': 0.0065689863209737, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 152.23048901886}
# {'code': 'ALL', 'alphaCode': 'ALL', 'numericCode': '008', 'name': 'Albanian lek', 'rate': 0.092049927226082, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 10.863669642496}
# {'code': 'MUR', 'alphaCode': 'MUR', 'numericCode': '480', 'name': 'Mauritian Rupee', 'rate': 0.036960025868898, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 27.056258119167}
# {'code': 'DOP', 'alphaCode': 'DOP', 'numericCode': '214', 'name': 'Dominican Peso', 'rate': 0.045257196484744, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 22.09593341331}
# {'code': 'NZD', 'alphaCode': 'NZD', 'numericCode': '554', 'name': 'New Zealand Dollar', 'rate': 0.0012002057752671, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 833.1904583424}
# {'code': 'HRK', 'alphaCode': 'HRK', 'numericCode': '191', 'name': 'Croatian Kuna', 'rate': 0.0056456361645834, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 177.12795703579}
# {'code': 'DZD', 'alphaCode': 'DZD', 'numericCode': '012', 'name': 'Algerian Dinar', 'rate': 0.11775203461561, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 8.4924222605954}
# {'code': 'ARS', 'alphaCode': 'ARS', 'numericCode': '032', 'name': 'Argentine Peso', 'rate': 0.090088686254332, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 11.100172969299}
# {'code': 'STN', 'alphaCode': 'STN', 'numericCode': '930', 'name': 'São Tomé and Príncipe Dobra', 'rate': 0.018518877314964, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 53.998953769837}
# {'code': 'BIF', 'alphaCode': 'BIF', 'numericCode': '108', 'name': 'Burundian franc', 'rate': 1.686920720932, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.59279608554901}
# {'code': 'SZL', 'alphaCode': 'SZL', 'numericCode': '748', 'name': 'Swazi lilangeni', 'rate': 0.012402431215867, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 80.629352632142}
# {'code': 'SOS', 'alphaCode': 'SOS', 'numericCode': '706', 'name': 'Somali shilling', 'rate': 0.47592088438129, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 2.1011895733469}
# {'code': 'ANG', 'alphaCode': 'ANG', 'numericCode': '532', 'name': 'Neth. Antillean Guilder', 'rate': 0.0014758037533165, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 677.59686730212}
# {'code': 'PKR', 'alphaCode': 'PKR', 'numericCode': '586', 'name': 'Pakistani Rupee', 'rate': 0.14849541264918, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 6.7342147623273}
# {'code': 'MXN', 'alphaCode': 'MXN', 'numericCode': '484', 'name': 'Mexican Peso', 'rate': 0.016954105521942, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 58.982763715008}
# {'code': 'UAH', 'alphaCode': 'UAH', 'numericCode': '980', 'name': 'Ukrainian Hryvnia', 'rate': 0.0246305527844, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 40.599982012314}
# {'code': 'CRC', 'alphaCode': 'CRC', 'numericCode': '188', 'name': 'Costa Rican Colón', 'rate': 0.52963660493841, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 1.8880870216972}
# {'code': 'BZD', 'alphaCode': 'BZD', 'numericCode': '084', 'name': 'Belize dollar', 'rate': 0.0016582507722358, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 603.04509833077}
# {'code': 'GNF', 'alphaCode': 'GNF', 'numericCode': '324', 'name': 'Guinean franc', 'rate': 7.3534247709939, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.13599105602393}
# {'code': 'ERN', 'alphaCode': 'ERN', 'numericCode': '232', 'name': 'Eritrean nakfa', 'rate': 0.012398065699775, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 80.657743249267}
# {'code': 'WST', 'alphaCode': 'WST', 'numericCode': '882', 'name': 'Samoan tala', 'rate': 0.0021221174028835, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 471.22746302406}
# {'code': 'EGP', 'alphaCode': 'EGP', 'numericCode': '818', 'name': 'Egyptian Pound', 'rate': 0.012961303123613, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 77.152736145658}
# {'code': 'SGD', 'alphaCode': 'SGD', 'numericCode': '702', 'name': 'Singapore Dollar', 'rate': 0.0011176543630341, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 894.73099472837}
# {'code': 'XAF', 'alphaCode': 'XAF', 'numericCode': '950', 'name': 'Central African CFA Franc', 'rate': 0.49115830519192, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 2.036003442127}
# {'code': 'AMD', 'alphaCode': 'AMD', 'numericCode': '051', 'name': 'Armenia Dram', 'rate': 0.4121428930528, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 2.4263429428392}
# {'code': 'PYG', 'alphaCode': 'PYG', 'numericCode': '600', 'name': 'Paraguayan Guaraní', 'rate': 5.7503008956901, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.17390394313965}
# {'code': 'GYD', 'alphaCode': 'GYD', 'numericCode': '328', 'name': 'Guyanese dollar', 'rate': 0.17203724066163, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 5.8126949499664}
# {'code': 'RWF', 'alphaCode': 'RWF', 'numericCode': '646', 'name': 'Rwandan franc', 'rate': 0.83525977360823, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 1.1972323241189}
# {'code': 'SYP', 'alphaCode': 'SYP', 'numericCode': '760', 'name': 'Syrian pound', 'rate': 2.0719355678271, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.4826404911079}
# {'code': 'MOP', 'alphaCode': 'MOP', 'numericCode': '446', 'name': 'Macanese pataca', 'rate': 0.006630817894025, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 150.81095816266}
# {'code': 'BAM', 'alphaCode': 'BAM', 'numericCode': '977', 'name': 'Bosnia and Herzegovina convertible mark', 'rate': 0.0014674375975112, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 681.45998282723}
# {'code': 'INR', 'alphaCode': 'INR', 'numericCode': '356', 'name': 'Indian Rupee', 'rate': 0.06259223988001, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 15.97642138893}
# {'code': 'TRY', 'alphaCode': 'TRY', 'numericCode': '949', 'name': 'Turkish Lira', 'rate': 0.012151360530108, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 82.295311502134}
# {'code': 'VND', 'alphaCode': 'VND', 'numericCode': '704', 'name': 'Vietnamese Dong', 'rate': 18.870919841109, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.052991587501821}
# {'code': 'KGS', 'alphaCode': 'KGS', 'numericCode': '417', 'name': 'Kyrgyzstan Som', 'rate': 0.079116375772706, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 12.639608301484}
# {'code': 'AFN', 'alphaCode': 'AFN', 'numericCode': '971', 'name': 'Afghan afghani', 'rate': 0.072185479358667, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 13.853201625653}
# {'code': 'NAD', 'alphaCode': 'NAD', 'numericCode': '516', 'name': 'Namibian dollar', 'rate': 0.012402431215867, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 80.629352632142}
# {'code': 'MWK', 'alphaCode': 'MWK', 'numericCode': '454', 'name': 'Malawian kwacha', 'rate': 0.6637065131536, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 1.5066900507703}
# {'code': 'GTQ', 'alphaCode': 'GTQ', 'numericCode': '320', 'name': 'Guatemalan Quetzal', 'rate': 0.0063384748340942, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 157.76665935803}
# {'code': 'NOK', 'alphaCode': 'NOK', 'numericCode': '578', 'name': 'Norwegian Krone', 'rate': 0.0072842630309794, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 137.28224746238}
# {'code': 'LBP', 'alphaCode': 'LBP', 'numericCode': '422', 'name': 'Lebanese Pound', 'rate': 1.253508880812, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.79776060250346}
# {'code': 'HUF', 'alphaCode': 'HUF', 'numericCode': '348', 'name': 'Hungarian Forint', 'rate': 0.27748957415099, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 3.6037389983375}
# {'code': 'PEN', 'alphaCode': 'PEN', 'numericCode': '604', 'name': 'Peruvian Nuevo Sol', 'rate': 0.003078177482318, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 324.86755742458}
# {'code': 'RSD', 'alphaCode': 'RSD', 'numericCode': '941', 'name': 'Serbian Dinar', 'rate': 0.088001727730305, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 11.363413262347}
# {'code': 'SVC', 'alphaCode': 'SVC', 'numericCode': '222', 'name': 'Salvadoran colon', 'rate': 0.0072015752715317, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 138.85850835345}
# {'code': 'XCD', 'alphaCode': 'XCD', 'numericCode': '951', 'name': 'East Caribbean Dollar', 'rate': 0.0022307096043737, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 448.28784438787}
# {'code': 'MMK', 'alphaCode': 'MMK', 'numericCode': '104', 'name': 'Myanma Kyat', 'rate': 1.4627452098447, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.68364606034577}
# {'code': 'MVR', 'alphaCode': 'MVR', 'numericCode': '462', 'name': 'Maldivian rufiyaa', 'rate': 0.012720442272684, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 78.613618816339}
# {'code': 'VES', 'alphaCode': 'VES', 'numericCode': '928', 'name': 'Venezuelan Bolivar', 'rate': 0.0035261711783311, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 283.59371948395}
# {'code': 'NPR', 'alphaCode': 'NPR', 'numericCode': '524', 'name': 'Nepalese Rupee', 'rate': 0.10057177266684, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 9.9431477986637}
# {'code': 'ISK', 'alphaCode': 'ISK', 'numericCode': '352', 'name': 'Icelandic Krona', 'rate': 0.10609716702835, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 9.4253223531674}
# {'code': 'GIP', 'alphaCode': 'GIP', 'numericCode': '292', 'name': 'Gibraltar pound', 'rate': 0.0006282277047123, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 1591.7795291406}
# {'code': 'GEL', 'alphaCode': 'GEL', 'numericCode': '981', 'name': 'Georgian lari', 'rate': 0.0026181667532206, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 381.94664215711}
# {'code': 'MKD', 'alphaCode': 'MKD', 'numericCode': '807', 'name': 'Macedonian denar', 'rate': 0.046117765597911, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 21.683617734622}
# {'code': 'AWG', 'alphaCode': 'AWG', 'numericCode': '533', 'name': 'Aruban florin', 'rate': 0.0014892146394834, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 671.49487621672}
# {'code': 'SLL', 'alphaCode': 'SLL', 'numericCode': '694', 'name': 'Sierra Leonean leone', 'rate': 9.5714414818099, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.1044774710163}
# {'code': 'KES', 'alphaCode': 'KES', 'numericCode': '404', 'name': 'Kenyan shilling', 'rate': 0.094028042319975, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 10.635125174648}
# {'code': 'AED', 'alphaCode': 'AED', 'numericCode': '784', 'name': 'U.A.E Dirham', 'rate': 0.0030348468218266, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 329.50592194901}
# {'code': 'PHP', 'alphaCode': 'PHP', 'numericCode': '608', 'name': 'Philippine Peso', 'rate': 0.043067182193103, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 23.219536293697}
# {'code': 'MRO', 'alphaCode': 'MRO', 'numericCode': '478', 'name': 'Mauritanian Ouguiya', 'rate': 0.030012643972909, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 33.319290393164}
# {'code': 'COP', 'alphaCode': 'COP', 'numericCode': '170', 'name': 'Colombian Peso', 'rate': 3.1556646915096, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.31689044868757}
# {'code': 'BBD', 'alphaCode': 'BBD', 'numericCode': '052', 'name': 'Barbadian Dollar', 'rate': 0.0016610660058034, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 602.02303611431}
# {'code': 'DJF', 'alphaCode': 'DJF', 'numericCode': '262', 'name': 'Djiboutian franc', 'rate': 0.14645089457013, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 6.8282273244917}
# {'code': 'MZN', 'alphaCode': 'MZN', 'numericCode': '943', 'name': 'Mozambican metical', 'rate': 0.05272889918123, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 18.964932238827}
# {'code': 'UGX', 'alphaCode': 'UGX', 'numericCode': '800', 'name': 'Ugandan shilling', 'rate': 2.9475234019298, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.33926787463173}
# {'code': 'BRL', 'alphaCode': 'BRL', 'numericCode': '986', 'name': 'Brazilian Real', 'rate': 0.0041901704566864, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 238.65377562487}
# {'code': 'CNY', 'alphaCode': 'CNY', 'numericCode': '156', 'name': 'Chinese Yuan', 'rate': 0.0052409836286351, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 190.80387783246}
# {'code': 'SAR', 'alphaCode': 'SAR', 'numericCode': '682', 'name': 'Saudi Riyal', 'rate': 0.0030938070363865, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 323.22636422987}
# {'code': 'ZAR', 'alphaCode': 'ZAR', 'numericCode': '710', 'name': 'South African Rand', 'rate': 0.012340640835983, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 81.03306897031}
# {'code': 'MDL', 'alphaCode': 'MDL', 'numericCode': '498', 'name': 'Moldova Lei', 'rate': 0.015182730081112, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 65.864307318753}
# {'code': 'PAB', 'alphaCode': 'PAB', 'numericCode': '590', 'name': 'Panamanian Balboa', 'rate': 0.00082359210007753, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 1214.1932880438}
# {'code': 'FJD', 'alphaCode': 'FJD', 'numericCode': '242', 'name': 'Fiji Dollar', 'rate': 0.0017437944776009, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 573.46207528757}
# {'code': 'CDF', 'alphaCode': 'CDF', 'numericCode': '976', 'name': 'Congolese franc', 'rate': 1.6459301239748, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.60755920645346}
# {'code': 'SDG', 'alphaCode': 'SDG', 'numericCode': '938', 'name': 'Sudanese pound', 'rate': 0.36690525680273, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 2.7254992439034}
# {'code': 'TOP', 'alphaCode': 'TOP', 'numericCode': '776', 'name': 'Tongan paʻanga', 'rate': 0.0018414316527113, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 543.05572434775}
# {'code': 'VUV', 'alphaCode': 'VUV', 'numericCode': '548', 'name': 'Vanuatu vatu', 'rate': 0.093017415303726, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 10.750674986342}
# {'code': 'DKK', 'alphaCode': 'DKK', 'numericCode': '208', 'name': 'Danish Krone', 'rate': 0.0055530243121658, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 180.08204966961}
# {'code': 'IDR', 'alphaCode': 'IDR', 'numericCode': '360', 'name': 'Indonesian Rupiah', 'rate': 11.831780848493, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.08451813068591}
# {'code': 'TND', 'alphaCode': 'TND', 'numericCode': '788', 'name': 'Tunisian Dinar', 'rate': 0.0024372019584215, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 410.30657986491}
# {'code': 'TWD', 'alphaCode': 'TWD', 'numericCode': '901', 'name': 'New Taiwan Dollar ', 'rate': 0.02335198820597, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 42.8229061774}
# {'code': 'IQD', 'alphaCode': 'IQD', 'numericCode': '368', 'name': 'Iraqi dinar', 'rate': 1.219242933324, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.82018109161698}
# {'code': 'BOB', 'alphaCode': 'BOB', 'numericCode': '068', 'name': 'Bolivian Boliviano', 'rate': 0.0056567032882677, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 176.78141296081}
# {'code': 'LRD', 'alphaCode': 'LRD', 'numericCode': '430', 'name': 'Liberian dollar', 'rate': 0.12624697008265, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 7.9209821775944}
# {'code': 'LAK', 'alphaCode': 'LAK', 'numericCode': '418', 'name': 'Lao kip', 'rate': 9.4431379766921, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.1058970018725}
# {'code': 'BWP', 'alphaCode': 'BWP', 'numericCode': '072', 'name': 'Botswana Pula', 'rate': 0.0095610490372045, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 104.59103348479}
# {'code': 'KWD', 'alphaCode': 'KWD', 'numericCode': '414', 'name': 'Kuwaiti Dinar', 'rate': 0.00025049333135413, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 3992.1222437106}
# {'code': 'CZK', 'alphaCode': 'CZK', 'numericCode': '203', 'name': 'Czech Koruna', 'rate': 0.018481758857053, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 54.107404372847}
# {'code': 'NGN', 'alphaCode': 'NGN', 'numericCode': '566', 'name': 'Nigerian Naira', 'rate': 0.34241851391953, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 2.9204028384838}
# {'code': 'TMT', 'alphaCode': 'TMT', 'numericCode': '934', 'name': 'New Turkmenistan Manat', 'rate': 0.002921080477786, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 342.3390788459}
# {'code': 'ETB', 'alphaCode': 'ETB', 'numericCode': '230', 'name': 'Ethiopian birr', 'rate': 0.042233698624774, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 23.677774681411}
# {'code': 'TTD', 'alphaCode': 'TTD', 'numericCode': '780', 'name': 'Trinidad Tobago Dollar', 'rate': 0.0055856176106978, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 179.03123158391}
# {'code': 'AOA', 'alphaCode': 'AOA', 'numericCode': '973', 'name': 'Angolan kwanza', 'rate': 0.38285765927239, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 2.6119367754075}
# {'code': 'KHR', 'alphaCode': 'KHR', 'numericCode': '116', 'name': 'Cambodian riel', 'rate': 3.3229155333076, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.30094054151434}
# {'code': 'MAD', 'alphaCode': 'MAD', 'numericCode': '504', 'name': 'Moroccan Dirham', 'rate': 0.0080591720292808, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 124.08222536593}
# {'code': 'RON', 'alphaCode': 'RON', 'numericCode': '946', 'name': 'Romanian New Leu', 'rate': 0.0036901350141861, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 270.99279461474}
# {'code': 'BYN', 'alphaCode': 'BYN', 'numericCode': '933', 'name': 'Belarussian Ruble', 'rate': 0.0024714375306872, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 404.62281064493}
# {'code': 'TJS', 'alphaCode': 'TJS', 'numericCode': '972', 'name': 'Tajikistan Ruble', 'rate': 0.010147042114266, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 98.550886922416}
# {'code': 'GMD', 'alphaCode': 'GMD', 'numericCode': '270', 'name': 'Gambian dalasi', 'rate': 0.043973663736654, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 22.74088431632}
# {'code': 'CVE', 'alphaCode': 'CVE', 'numericCode': '132', 'name': 'Cape Verde escudo', 'rate': 0.082877422713086, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 12.066012277697}
# {'code': 'HNL', 'alphaCode': 'HNL', 'numericCode': '340', 'name': 'Honduran Lempira', 'rate': 0.020196619640517, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 49.513236264246}
# {'code': 'SCR', 'alphaCode': 'SCR', 'numericCode': '690', 'name': 'Seychelles rupee', 'rate': 0.012009173083212, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 83.269680024674}
# {'code': 'BHD', 'alphaCode': 'BHD', 'numericCode': '048', 'name': 'Bahrain Dinar', 'rate': 0.00031041223902205, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 3221.5224604239}
# {'code': 'OMR', 'alphaCode': 'OMR', 'numericCode': '512', 'name': 'Omani Rial', 'rate': 0.00031712701079392, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 3153.3107113661}
# {'code': 'ILS', 'alphaCode': 'ILS', 'numericCode': '376', 'name': 'Israeli New Sheqel', 'rate': 0.0026707298500676, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 374.42948412573}
# {'code': 'LYD', 'alphaCode': 'LYD', 'numericCode': '434', 'name': 'Libyan Dinar', 'rate': 0.0038634320858701, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 258.83721462514}
# {'code': 'CLP', 'alphaCode': 'CLP', 'numericCode': '152', 'name': 'Chilean Peso', 'rate': 0.65945134755095, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 1.5164120957729}
# {'code': 'BSD', 'alphaCode': 'BSD', 'numericCode': '044', 'name': 'Bahamian Dollar', 'rate': 0.00082242702561551, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 1215.9133501864}
# {'code': 'XPF', 'alphaCode': 'XPF', 'numericCode': '953', 'name': 'CFP Franc', 'rate': 0.089586958956843, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 11.16233893464}
# {'code': 'LSL', 'alphaCode': 'LSL', 'numericCode': '426', 'name': 'Lesotho loti', 'rate': 0.01241117147747, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 80.572571397896}
# {'code': 'TZS', 'alphaCode': 'TZS', 'numericCode': '834', 'name': 'Tanzanian shilling', 'rate': 1.9060013340401, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.52465860445142}
# {'code': 'BDT', 'alphaCode': 'BDT', 'numericCode': '050', 'name': 'Bangladeshi taka', 'rate': 0.071439998609326, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 13.997760630828}
# {'code': 'QAR', 'alphaCode': 'QAR', 'numericCode': '634', 'name': 'Qatari Rial', 'rate': 0.0030101751258602, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 332.206585394}
# {'code': 'MYR', 'alphaCode': 'MYR', 'numericCode': '458', 'name': 'Malaysian Ringgit', 'rate': 0.003465845915856, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 288.52984935801}
# {'code': 'KZT', 'alphaCode': 'KZT', 'numericCode': '398', 'name': 'Kazakhstani Tenge', 'rate': 0.38949089442138, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 2.5674541159314}
# {'code': 'HTG', 'alphaCode': 'HTG', 'numericCode': '332', 'name': 'Haitian gourde', 'rate': 0.087067077624032, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 11.48539754967}
# {'code': 'BND', 'alphaCode': 'BND', 'numericCode': '096', 'name': 'Brunei Dollar', 'rate': 0.001120000783906, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 892.8565179325}
# {'code': 'KMF', 'alphaCode': 'KMF', 'numericCode': '174', 'name': '\tComoro franc', 'rate': 0.36886485132539, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 2.7110200291702}
# {'code': 'MRU', 'alphaCode': 'MRU', 'numericCode': '929', 'name': 'Mauritanian ouguiya', 'rate': 0.029926002254088, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 33.415756354941}
# {'code': 'MNT', 'alphaCode': 'MNT', 'numericCode': '496', 'name': 'Mongolian togrog', 'rate': 2.3977470832581, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.41705816555147}
# {'code': 'HKD', 'alphaCode': 'HKD', 'numericCode': '344', 'name': 'Hong Kong Dollar', 'rate': 0.0064487068676137, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 155.06984896804}
# {'code': 'THB', 'alphaCode': 'THB', 'numericCode': '764', 'name': 'Thai Baht', 'rate': 0.027470440930083, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 36.402764795264}
# {'code': 'XOF', 'alphaCode': 'XOF', 'numericCode': '952', 'name': 'West African CFA Franc', 'rate': 0.49095665152037, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 2.0368397024528}
# {'code': 'IRR', 'alphaCode': 'IRR', 'numericCode': '364', 'name': 'Iranian rial', 'rate': 35.072648207957, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 0.028512246753387}
# {'code': 'UYU', 'alphaCode': 'UYU', 'numericCode': '858', 'name': 'Uruguayan Peso', 'rate': 0.035099184658447, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 28.490690303239}
# {'code': 'JMD', 'alphaCode': 'JMD', 'numericCode': '388', 'name': 'Jamaican Dollar', 'rate': 0.12579608804665, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 7.9493727947182}
# {'code': 'SSP', 'alphaCode': 'SSP', 'numericCode': '728', 'name': 'South Sudanese pound', 'rate': 0.35375017227139, 'date': 'Fri, 18 Mar 2022 11:55:01 GMT', 'inverseRate': 2.8268537470359}

# %% [markdown]
# ## 환율 정보에서 `code`와 `rate`만 추출하여 출력하기
# __Sample Run:__
# ```
# USD 0.00086484208312665
# EUR 0.00072856130060557
# GBP 0.00062543395312534
# JPY 0.09507474341514
# AUD 0.0011633915091951
# ...
# ```

# %%
for item in rates:
    code=rates[item]['code']
    item=rates[item]['rate']
    print(code, item)
# Out:
# USD 0.00082475717453957
# EUR 0.00074596961214103
# GBP 0.00062633348065572
# CAD 0.0010423232459695
# JPY 0.097860642412073
# AUD 0.0011202490433524
# CHF 0.00077452339026491
# GHS 0.006005610341528
# CUP 0.00082242702561551
# JOD 0.00058436489124357
# BGN 0.0014588440422927
# PGK 0.0029038307602044
# UZS 9.0621233423006
# MGA 3.3291970371513
# SRD 0.016958548220058
# ZMW 0.014621380096746
# YER 0.20584948076127
# SEK 0.0077858595531055
# LKR 0.21977896030737
# PLN 0.0035024974983411
# RUB 0.084250490098443
# AZN 0.0014179247392682
# NIO 0.029425985507987
# SBD 0.0065689863209737
# ALL 0.092049927226082
# MUR 0.036960025868898
# DOP 0.045257196484744
# NZD 0.0012002057752671
# HRK 0.0056456361645834
# DZD 0.11775203461561
# ARS 0.090088686254332
# STN 0.018518877314964
# BIF 1.686920720932
# SZL 0.012402431215867
# SOS 0.47592088438129
# ANG 0.0014758037533165
# PKR 0.14849541264918
# MXN 0.016954105521942
# UAH 0.0246305527844
# CRC 0.52963660493841
# BZD 0.0016582507722358
# GNF 7.3534247709939
# ERN 0.012398065699775
# WST 0.0021221174028835
# EGP 0.012961303123613
# SGD 0.0011176543630341
# XAF 0.49115830519192
# AMD 0.4121428930528
# PYG 5.7503008956901
# GYD 0.17203724066163
# RWF 0.83525977360823
# SYP 2.0719355678271
# MOP 0.006630817894025
# BAM 0.0014674375975112
# INR 0.06259223988001
# TRY 0.012151360530108
# VND 18.870919841109
# KGS 0.079116375772706
# AFN 0.072185479358667
# NAD 0.012402431215867
# MWK 0.6637065131536
# GTQ 0.0063384748340942
# NOK 0.0072842630309794
# LBP 1.253508880812
# HUF 0.27748957415099
# PEN 0.003078177482318
# RSD 0.088001727730305
# SVC 0.0072015752715317
# XCD 0.0022307096043737
# MMK 1.4627452098447
# MVR 0.012720442272684
# VES 0.0035261711783311
# NPR 0.10057177266684
# ISK 0.10609716702835
# GIP 0.0006282277047123
# GEL 0.0026181667532206
# MKD 0.046117765597911
# AWG 0.0014892146394834
# SLL 9.5714414818099
# KES 0.094028042319975
# AED 0.0030348468218266
# PHP 0.043067182193103
# MRO 0.030012643972909
# COP 3.1556646915096
# BBD 0.0016610660058034
# DJF 0.14645089457013
# MZN 0.05272889918123
# UGX 2.9475234019298
# BRL 0.0041901704566864
# CNY 0.0052409836286351
# SAR 0.0030938070363865
# ZAR 0.012340640835983
# MDL 0.015182730081112
# PAB 0.00082359210007753
# FJD 0.0017437944776009
# CDF 1.6459301239748
# SDG 0.36690525680273
# TOP 0.0018414316527113
# VUV 0.093017415303726
# DKK 0.0055530243121658
# IDR 11.831780848493
# TND 0.0024372019584215
# TWD 0.02335198820597
# IQD 1.219242933324
# BOB 0.0056567032882677
# LRD 0.12624697008265
# LAK 9.4431379766921
# BWP 0.0095610490372045
# KWD 0.00025049333135413
# CZK 0.018481758857053
# NGN 0.34241851391953
# TMT 0.002921080477786
# ETB 0.042233698624774
# TTD 0.0055856176106978
# AOA 0.38285765927239
# KHR 3.3229155333076
# MAD 0.0080591720292808
# RON 0.0036901350141861
# BYN 0.0024714375306872
# TJS 0.010147042114266
# GMD 0.043973663736654
# CVE 0.082877422713086
# HNL 0.020196619640517
# SCR 0.012009173083212
# BHD 0.00031041223902205
# OMR 0.00031712701079392
# ILS 0.0026707298500676
# LYD 0.0038634320858701
# CLP 0.65945134755095
# BSD 0.00082242702561551
# XPF 0.089586958956843
# LSL 0.01241117147747
# TZS 1.9060013340401
# BDT 0.071439998609326
# QAR 0.0030101751258602
# MYR 0.003465845915856
# KZT 0.38949089442138
# HTG 0.087067077624032
# BND 0.001120000783906
# KMF 0.36886485132539
# MRU 0.029926002254088
# MNT 2.3977470832581
# HKD 0.0064487068676137
# THB 0.027470440930083
# XOF 0.49095665152037
# IRR 35.072648207957
# UYU 0.035099184658447
# JMD 0.12579608804665
# SSP 0.35375017227139

# %% [markdown]
# ## `code`를 key, `rate`를 value로 하는 dict type의 `krw_rates` 만들기
# - 위의 코드를 수정하여 새로운 dict type의 객체 `krw_rates`를 만들어 `key`로 `rate`를 쉽게 찾는데 활용하려고 합니다.
# - 즉 `krw_rates['USD']`의 형식을 사용하여 환율 정보를 쉽게 접근할 수 있도록 하는 작업입니다.
# - 다른 말로, 위에서 출력해본 `code, rate` 정보를 모두 `krw_rates`에 저장하는 것입니다.
#
# __Sample Run:__
# ```
# 0.00086484208312665
# 0.00072856130060557
# 0.09507474341514
# 0.001084071583917
# ```

# %%
krw_rates = dict()   # empty name in dict type 

for item in rates:
    code=rates[item]['code']
    item=rates[item]['rate']
    krw_rates[code]=item

print('USD:', krw_rates['USD']) 
print('EUR:', krw_rates['EUR'])
print('JPY:', krw_rates['JPY'])
print('CAD:', krw_rates['CAD'])
# Out:
# USD: 0.00082475717453957
# EUR: 0.00074596961214103
# JPY: 0.097860642412073
# CAD: 0.0010423232459695

# %% [markdown]
# ## 환율 계산 하기
# 거의 다 했습니다. 이제 환율을 계산해봅니다. 여기서 제공되는 환율은 Korean Won(KRW)으로 1원에 대한 다른 통화의 가격입니다. 그러므로, 대개 숫자가 낮은 값으로 출력됨으로, 1000원에 대한 환율을 계산하여 봅시다.
# - `krw_rates[]`로 출력되는 값들은 모두 문자열(`str`) 타입이므로 `float()`로 변환하는 것이 필요합니다.
#
# __Sample Run:__
# ```
# 0.86484208312665
# 0.72856130060557
# 95.07474341513999
# 1.084071583917
# ```

# %%
krw_rates = dict()
for item in rates:
    code=rates[item]['code']
    item=rates[item]['rate']
    krw_rates[code]=float(item)*1000

print('USD:', krw_rates['USD']) 
print('EUR:', krw_rates['EUR'])
print('JPY:', krw_rates['JPY'])
print('CAD:', krw_rates['CAD'])
# Out:
# USD: 0.8247571745395701
# EUR: 0.74596961214103
# JPY: 97.860642412073
# CAD: 1.0423232459695

# %% [markdown]
# ## 환율 정보에서 `date`를 추출하여 `krw_rates`에 추가하기
# - 환율 정보에서 빼놓을 수 없는 정보는 `date`입니다. `rate`와 더불어 `date`정보를 추가하려고 합니다. `krw_rates`의 `key`는 변함없이 각 통화 `code`값들(e.g. 'USD', 'EUR', etc.)이지만, `value`로 `rate`뿐만 아니라 `date`를 포함하여 정보를 유지관리하고 보호하려고 합니다. 다음과 같은 dict type을 만들려고 하는 것입니다. 이것을 어떻게 구현할 수 있겠습니까?
#
# ```
# {
#   'USD': ('Sat, 4 Sep 2021 23:55:01 GMT', '0.00086484208312665'),
#   'EUR': ('Sat, 4 Sep 2021 23:55:01 GMT', '0.00072856130060557'),
#  ...
# }
# ```
# 값이 여러 개일 경우에는 list, tuple, dict types을 사용하여 하나로 묶어야 합니다. 자료를 수정하지 아니하도록 여기서는 tuple을 사용하도록 합니다.
#
# __Sample Run:__
# ```
# Sat, 4 Sep 2021 23:55:01 GMT 0.86484208312665
# Sat, 4 Sep 2021 23:55:01 GMT 0.72856130060557
# Sat, 4 Sep 2021 23:55:01 GMT 95.07474341513999
# Sat, 4 Sep 2021 23:55:01 GMT 1.084071583917
# ```

# %%
krw_rates = dict()   # empty name in dict type 

for item in rates:
    code=rates[item]['code']
    item=rates[item]['rate']
    date=rates[item]['date']
    krw_rates[code]=(date, float(item)*1000)

print('USD:', krw_rates['USD']) 
print('EUR:', krw_rates['EUR'])
print('JPY:', krw_rates['JPY'])
print('CAD:', krw_rates['CAD'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_c/5z9grn611_70x4_hw3rpx3040000gn/T/ipykernel_18943/3450151780.py in <module>
#       4     code=rates[item]['code']
#       5     item=rates[item]['rate']
# ----> 6     date=rates[item]['date']
#       7     krw_rates[code]=(date, float(item)*1000)
#       8
#
# KeyError: 0.00082475717453957

# %% [markdown]
# --------
# 슬기로운 자는 재앙을 보면 숨어 피하여도 어리석은 자들은 나가다가 해를 받느니라.
# 잠언22:3, 27:12

# %% [markdown]
# On my honour, I pledge that I have neither received nor provided improper assistance
# in the completion of this assignment.
# Signed: 최윤영 Student Number: 22100748
